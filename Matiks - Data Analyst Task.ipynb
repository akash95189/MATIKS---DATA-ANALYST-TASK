# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Matiks - Data Analyst Data - Sheet1.csv')
df.head()
# Out:
#                                 User_ID          Username  \
# 0  7280e6c4-6f7c-45dd-a8fc-c58389ea8e07  geoffreyanderson
# 1  23c48d4f-f5d0-4ff4-ba0f-2007441b9b57   riverachristian
# 2  cf8d530c-c137-4346-a78b-e76e36d45e2a        brownchris
# 3  47fcbe87-a1c1-40c3-b450-1b5692f61538     christopher90
# 4  0b620a32-9e77-4b4a-9931-f0b654bef095          vfreeman
#
#                       Email  Signup_Date   Country  Age  Gender Device_Type  \
# 0   haleymitchell@gmail.com  15-Dec-2024   Austria   22   Other      Mobile
# 1  masonmelissa@hotmail.com  07-Mar-2024     Gabon   22   Other          PC
# 2     mnichols@mcmillan.net  19-Oct-2023   Ireland   36  Female          PC
# 3         ttaylor@gmail.com  28-Sep-2023   Belarus   23   Other          PC
# 4        amanda80@gmail.com  09-Aug-2024  Slovenia   26   Other          PC
#
#   Game_Title  Total_Play_Sessions  Avg_Session_Duration_Min  \
# 0  MysticWar                   21                      5.78
# ...

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   User_ID                   10000 non-null  object
#  1   Username                  10000 non-null  object
#  2   Email                     10000 non-null  object
#  3   Signup_Date               10000 non-null  object
#  4   Country                   10000 non-null  object
#  5   Age                       10000 non-null  int64
#  6   Gender                    10000 non-null  object
#  7   Device_Type               10000 non-null  object
#  8   Game_Title                10000 non-null  object
#  9   Total_Play_Sessions       10000 non-null  int64
#  10  Avg_Session_Duration_Min  10000 non-null  float64
#  11  Total_Hours_Played        10000 non-null  float64
#  12  In_Game_Purchases_Count   10000 non-null  int64
# ...

# %%
df.dtypes
# Out:
# User_ID                      object
# Username                     object
# Email                        object
# Signup_Date                  object
# Country                      object
# Age                           int64
# Gender                       object
# Device_Type                  object
# Game_Title                   object
# Total_Play_Sessions           int64
# Avg_Session_Duration_Min    float64
# Total_Hours_Played          float64
# In_Game_Purchases_Count       int64
# Total_Revenue_USD           float64
# Last_Login                   object
# Subscription_Tier            object
# Referral_Source              object
# Preferred_Game_Mode          object
# Rank_Tier                    object
# Achievement_Score             int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# User_ID                     0
# Username                    0
# Email                       0
# Signup_Date                 0
# Country                     0
# Age                         0
# Gender                      0
# Device_Type                 0
# Game_Title                  0
# Total_Play_Sessions         0
# Avg_Session_Duration_Min    0
# Total_Hours_Played          0
# In_Game_Purchases_Count     0
# Total_Revenue_USD           0
# Last_Login                  0
# Subscription_Tier           0
# Referral_Source             0
# Preferred_Game_Mode         0
# Rank_Tier                   0
# Achievement_Score           0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age  Total_Play_Sessions  Avg_Session_Duration_Min  \
# count  10000.000000         10000.000000              10000.000000
# mean      31.063700            19.993900                 30.035238
# std       10.687547             4.492314                 10.062647
# min       13.000000             6.000000                 -5.640000
# 25%       22.000000            17.000000                 23.210000
# 50%       31.000000            20.000000                 29.860000
# 75%       40.000000            23.000000                 36.902500
# max       49.000000            42.000000                 75.620000
#
#        Total_Hours_Played  In_Game_Purchases_Count  Total_Revenue_USD  \
# count        10000.000000              10000.00000       10000.000000
# mean           100.216981                  4.97600          50.177466
# std             49.642141                  2.23623          49.600884
# min            -89.730000                  0.00000           0.000000
# ...

# %%
df.boxplot(df,x='Achievement_Score')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.boxplot(df,x='Achievement_Score')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:516, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     499 @Substitution(backend=_backend_doc)
#     500 @Appender(_boxplot_doc)
#     501 def boxplot_frame(
#    (...)
#     513     **kwargs,
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#     519         by=by,
#     520         ax=ax,
#     521         fontsize=fontsize,
#     522         rot=rot,
#     523         grid=grid,
#     524         figsize=figsize,
#     525         layout=layout,
#     526         return_type=return_type,
# ...

# %%
sns.lineplot(df,x='Signup_Date', y='Total_Revenue_USD')
# Out:
# <Axes: xlabel='Signup_Date', ylabel='Total_Revenue_USD'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Username', 'Email', 'Signup_Date', 'Country', 'Age',
#        'Gender', 'Device_Type', 'Game_Title', 'Total_Play_Sessions',
#        'Avg_Session_Duration_Min', 'Total_Hours_Played',
#        'In_Game_Purchases_Count', 'Total_Revenue_USD', 'Last_Login',
#        'Subscription_Tier', 'Referral_Source', 'Preferred_Game_Mode',
#        'Rank_Tier', 'Achievement_Score'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
dia = sns.barplot(df,x='Device_Type', y='Total_Revenue_USD',hue='Preferred_Game_Mode', errwidth=0)
for container in dia.containers:
    dia.bar_label(container)

# %%
plt.figure(figsize=(10,8))
dia = sns.barplot(df,x='Preferred_Game_Mode', y='Avg_Session_Duration_Min',hue='Gender', errwidth=0)
for container in dia.containers:
    dia.bar_label(container)

# %%
plt.figure(figsize=(10,8))
dia = sns.barplot(df,x='Device_Type', y='Total_Revenue_USD',hue='Gender', errwidth=0)
for container in dia.containers:
    dia.bar_label(container)

# %%
df.columns
# Out:
# Index(['User_ID', 'Username', 'Email', 'Signup_Date', 'Country', 'Age',
#        'Gender', 'Device_Type', 'Game_Title', 'Total_Play_Sessions',
#        'Avg_Session_Duration_Min', 'Total_Hours_Played',
#        'In_Game_Purchases_Count', 'Total_Revenue_USD', 'Last_Login',
#        'Subscription_Tier', 'Referral_Source', 'Preferred_Game_Mode',
#        'Rank_Tier', 'Achievement_Score'],
#       dtype='object')

# %%
df['Rank_Tier'].unique()
# Out:
# array(['Bronze', 'Platinum', 'Diamond', 'Gold', 'Silver'], dtype=object)

# %%
df['Game_Title'].unique()
# Out:
# array(['MysticWar', 'QuestRaid', 'BattleZone', 'SpeedRun'], dtype=object)

# %%
plt.figure(figsize=(10,8))
dia = sns.barplot(df,x='Game_Title', y='Avg_Session_Duration_Min',hue='Preferred_Game_Mode', errwidth=0)
for container in dia.containers:
    dia.bar_label(container)

# %%
plt.figure(figsize=(12,10))
dia = sns.barplot(df,x='Game_Title', y='Avg_Session_Duration_Min',hue='Rank_Tier', errwidth=0)
for container in dia.containers:
    dia.bar_label(container)

# %%
plt.figure(figsize=(10,8))
dia = sns.barplot(df,x='Game_Title', y='Achievement_Score',hue='Preferred_Game_Mode', errwidth=0)
for container in dia.containers:
    dia.bar_label(container)

# %%
plt.figure(figsize=(12,10))
dia = sns.barplot(df,x='Game_Title', y='Achievement_Score',hue='Rank_Tier', errwidth=0)
for container in dia.containers:
    dia.bar_label(container)

# %%
df['Country'].unique()
# Out:
# array(['Austria', 'Gabon', 'Ireland', 'Belarus', 'Slovenia', 'Cape Verde',
#        'Niger', 'Australia', 'Cameroon', 'Morocco',
#        'Heard Island and McDonald Islands', 'Samoa',
#        'United States Minor Outlying Islands', 'Reunion',
#        'Northern Mariana Islands', 'Guadeloupe', 'Jersey', 'Japan',
#        'Vanuatu', 'Togo', 'Solomon Islands', 'El Salvador', 'France',
#        'British Virgin Islands', 'Nauru', 'Anguilla',
#        'Saint Pierre and Miquelon', 'Afghanistan', 'Haiti', 'Bangladesh',
#        'Andorra', 'Estonia', 'Moldova', 'Germany', 'Vietnam', 'Honduras',
#        'Namibia', 'Lithuania', 'Gambia', 'Nicaragua', 'Romania',
#        'South Georgia and the South Sandwich Islands', 'Malaysia',
#        'Armenia', 'Rwanda', 'Kenya', 'Tunisia', 'Montserrat',
#        'Brunei Darussalam', 'Iceland', 'Guinea-Bissau',
#        'Papua New Guinea', 'French Polynesia', 'Cyprus',
#        'Syrian Arab Republic', 'Uzbekistan', 'Equatorial Guinea',
# ...

# %%
sns.barplot(df,x='Device_Type', y='Total_Play_Sessions')
# Out:
# <Axes: xlabel='Device_Type', ylabel='Total_Play_Sessions'>
